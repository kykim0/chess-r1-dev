# %%
import spacy
import cupy
import thinc

try:
    print(f"CuPy version: {cupy.__version__}")
    print(f"Is CUDA available for CuPy? {cupy.is_available()}")
    
    activated = spacy.require_gpu()
    print(f"spaCy GPU activation: {activated}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# CuPy version: 13.6.0
# Is CUDA available for CuPy? True
# spaCy GPU activation: True
